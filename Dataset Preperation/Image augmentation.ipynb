# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# To work with numpy arrays.
import numpy as np 

# To create the convolution neural network
import keras 

# To provide with the name of the images.
import glob

# To read rgb values of images.
import cv2

# To open the image so it can be resized.
from PIL import Image

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# !cd '/content/drive/My Drive/Minor project/Math equation project/symbol'

# %%
# !unzip '/content/drive/My Drive/Minor project/Math equation project/symbol/symbol'
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# #reading files from division folder and augmenting them
# file = glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/div_images/*.jpg')

# aug=[]

# for im in file:
#   img=cv2.imread(im)
#   aug.append(np.fliplr(img))  
#   aug.append(np.flipud(img))

# %%
# #saving the augmented images in another folder

# count=770
# for i in aug:  
#   cv2.imwrite('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/augment_div/'+str(count)+'.jpg',i)
#   count+=1

# %%
# #count of no. of files in division operator folder 
# p=0
# for i in file:
#   p+=1
# print(p)
# Out:
# 769

# %%
#file = glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/augment_div/*.jpg')
#for i in file:
#  print(i)

# %%
# #count of no. of augmented files of division operator
# p=0
# for i in aug:
#   p+=1
# print(p)
# Out:
# 1538

# %%
z_images=glob.glob('./symbol/0_images/*.jpg')

i=1 
for image in z_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/0_images/'+str(i)+'.jpg')
    i=i+1

# %%
o_images=glob.glob('./symbol/1_images/*.jpg')

i=1 
for image in o_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/1_images/'+str(i)+'.jpg')
    i=i+1

# %%
t_images=glob.glob('./symbol/2_images/*.jpg')

i=1 
for image in t_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/2_images/'+str(i)+'.jpg')
    i=i+1

# %%
th_images=glob.glob('./symbol/3_images/*.jpg')

i=1 
for image in th_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/3_images/'+str(i)+'.jpg')
    i=i+1

# %%
f_images=glob.glob('./symbol/4_images/*.jpg')

i=1 
for image in f_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/4_images/'+str(i)+'.jpg')
    i=i+1

# %%
fi_images=glob.glob('./symbol/5_images/*.jpg')

i=1 
for image in fi_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/5_images/'+str(i)+'.jpg')
    i=i+1

# %%
s_images=glob.glob('./symbol/6_images/*.jpg')

i=1 
for image in s_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/6_images/'+str(i)+'.jpg')
    i=i+1

# %%
se_images=glob.glob('./symbol/7_images/*.jpg')

i=1 
for image in se_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/7_images/'+str(i)+'.jpg')
    i=i+1

# %%
e_images=glob.glob('./symbol/8_images/*.jpg')

i=1 
for image in e_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/8_images/'+str(i)+'.jpg')
    i=i+1

# %%
n_images=glob.glob('./symbol/9_images/*.jpg')

i=1 
for image in n_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/numbers/9_images/'+str(i)+'.jpg')
    i=i+1

# %%
lp_images=glob.glob('./symbol/lp_images/*.jpg')

i=1 
for image in lp_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/parenthesis/lp_images/'+str(i)+'.jpg')
    i=i+1

# %%
rp_images=glob.glob('./symbol/rp_images/*.jpg')

i=1 
for image in rp_images :
    open_image=Image.open(image)
    
    open_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/parenthesis/rp_images/'+str(i)+'.jpg')
    i=i+1

# %%
#zero images
p=0
for i in z_images:
  p=p+1
print(p)
# Out:
# 6914

# %%
#one images
p=0
for i in o_images:
  p=p+1
print(p)
# Out:
# 6914

# %%
#two images
p=0
for i in t_images:
  p=p+1
print(p)
# Out:
# 26141

# %%
#three images
p=0
for i in th_images:
  p=p+1
print(p)
# Out:
# 10909

# %%
#four images
p=0
for i in f_images:
  p=p+1
print(p)
# Out:
# 7396

# %%
#five images

p=0
for i in fi_images:
  p=p+1
print(p)
# Out:
# 3544

# %%
#six images
p=0
for i in s_images:
  p=p+1
print(p)
# Out:
# 3118

# %%
#seven images
p=0
for i in se_images:
  p=p+1
print(p)
# Out:
# 2909

# %%
#EIGHT IMAGES
p=0
for i in e_images:
  p=p+1
print(p)
# Out:
# 3068

# %%
#nie images
p=0
for i in n_images:
  p=p+1
print(p)
# Out:
# 3737

# %%
#left prenthesis
p=0
for i in lp_images:
  p=p+1
print(p)
# Out:
# 14294

# %%
#right parenthesis
p=0
for i in rp_images:
  p=p+1
print(p)
# Out:
# 14355

# %%
#Converting the operator images to  one channel.

sum_images=glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/sum_images/*.jpg')

i=1 
for image in sum_images :
    new_image=Image.open(image).convert("L")
    
    new_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/grayscale/sum_images_gray/'+str(i)+'.jpg')
    i=i+1

sub_images=glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/sub_images/*.jpg')

i=1 
for image in sub_images :
    new_image=Image.open(image).convert("L")
    
    new_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/grayscale/sub_images_gray/'+str(i)+'.jpg')
    i=i+1

mul_images=glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/mul_images/*.jpg')

i=1 
for image in mul_images :
    new_image=Image.open(image).convert("L")
    
    new_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/grayscale/mul_images_gray/'+str(i)+'.jpg')
    i=i+1

    
div_images=glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/operator/div_images/*.jpg')

i=1 
for image in div_images :
    new_image=Image.open(image).convert("L")
    
    new_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/grayscale/div_images_gray/'+str(i)+'.jpg')
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-f4a7e5f56257> in <module>()
#       4 i=1
#       5 for image in sum_images :
# ----> 6     new_image=Image.open(image).convert("L")
#       7
#       8     new_image.save('/content/drive/My Drive/Minor project/Math equation project/symbol/grayscale/sum_images_gray/'+str(i)+'.jpg')
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2537         exclusive_fp = True
#    2538
# -> 2539     prefix = fp.read(16)
#    2540
#    2541     preinit()
#
# KeyboardInterrupt:

# %%
fake_images=glob.glob('/content/drive/My Drive/Minor project/Math equation project/symbol/grayscale/div_images_gray/1.jpg')
a=cv2.imread(fake_images[0])
a.shape
